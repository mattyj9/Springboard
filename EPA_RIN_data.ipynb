# %%
import html5lib
import requests
URL = "https://www.epa.gov/fuels-registration-reporting-and-compliance-help/rins-generated-transactions"
r = requests.get(URL)
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<!--[if IEMobile 7]><html class="iem7 no-js" lang="en" dir="ltr"><![endif]-->\n<!--[if lt IE 7]><html class="lt-ie9 lt-ie8 lt-ie7 no-js" lang="en" dir="ltr"><![endif]-->\n<!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8 no-js" lang="en" dir="ltr"><![endif]-->\n<!--[if IE 8]><html class="lt-ie9 no-js" lang="en" dir="ltr"><![endif]-->\n<!--[if (gt IE 8)|(gt IEMobile 7)]><!--> <html class="no-js not-oldie" lang="en" dir="ltr"> <!--<![endif]-->\n<head>\n  <meta charset="utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VgEFVVRQGwEBXVRTBQcP",licenseKey:"ead36e43ac",applicationID:"21951268"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.content, 'html5lib')
print(soup.prettyify())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-233624b9e9b4> in <module>
#       1 from bs4 import BeautifulSoup
#       2 soup = BeautifulSoup(r.content, 'html5lib')
# ----> 3 print(soup.prettyify())
#
# TypeError: 'NoneType' object is not callable
